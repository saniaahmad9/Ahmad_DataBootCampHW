# %%
import matplotlib.pyplot as plt
import pandas as pd
import numpy as np
import requests
import time

# Import API key
api_keys = "32df13d8bbd8d55bfc220a0ecc23c6f8"

# Incorporated citipy to determine city based on latitude and longitude
from citipy import citipy

# Output File (CSV)
output_data_file = "output_data/cities.csv"

# Range of latitudes and longitudes
lat_range = (-90, 90)
lng_range = (-180, 180)

# %%
# List for holding lat_lngs and cities
lat_lngs = []
cities = []

# Create a set of random lat and lng combinations
lats = np.random.uniform(low=-90.000, high=90.000, size=1500)
lngs = np.random.uniform(low=-180.000, high=180.000, size=1500)
lat_lngs = zip(lats, lngs)

# Identify nearest city for each lat, lng combination
for lat_lng in lat_lngs:
    city = citipy.nearest_city(lat_lng[0], lat_lng[1]).city_name
    
    # If the city is unique, then add it to a our cities list
    if city not in cities:
        cities.append(city)

# Print the city count to confirm sufficient count
len(cities)
# Out:
# 613

# %%
url = "http://api.openweathermap.org/data/2.5/weather?"
units = "metric"

# Build partial query URL
query_url = f"{url}appid={api_keys}&units={units}&q="

print(query_url)
# Out:
# http://api.openweathermap.org/data/2.5/weather?appid=32df13d8bbd8d55bfc220a0ecc23c6f8&units=metric&q=

# %%
lat = []
temp = []
humidity = []
cloud = []
wind = []

# Loop through the list of cities and perform a request for data on each
counter = 1

print("Beginning Data Retrieval")   
print("--------------------------------")  

for city in cities:
    
    response = requests.get(query_url + city).json()

    try:
        lat.append(response['coord']['lat'])
        temp.append(response['main']['temp'])
        humidity.append(response['main']['humidity'])
        cloud.append(response['clouds']['all'])
        wind.append(response['wind']['speed'])
        print(f"Processing Record {counter} | {city}") 
        counter+=1
        time.sleep(1)
    except KeyError:
        print("City not found. Skipping...")
# Out:
# Beginning Data Retrieval
# --------------------------------
# Processing Record 1 | provideniya
# Processing Record 2 | dikson
# Processing Record 3 | santa rosa
# Processing Record 4 | hermanus
# Processing Record 5 | bredasdorp
# Processing Record 6 | gotsu
# Processing Record 7 | biak
# Processing Record 8 | mar del plata
# Processing Record 9 | hervey bay
# Processing Record 10 | butaritari
# Processing Record 11 | palmer
# Processing Record 12 | aketi
# Processing Record 13 | yellowknife
# Processing Record 14 | rikitea
# Processing Record 15 | avera
# Processing Record 16 | marathon
# Processing Record 17 | albany
# Processing Record 18 | saint-philippe
# Processing Record 19 | ushuaia
# Processing Record 20 | mataura
# Processing Record 21 | hilo
# City not found. Skipping...
# Processing Record 22 | puri
# Processing Record 23 | thompson
# Processing Record 24 | chuy
# Processing Record 25 | alice springs
# Processing Record 26 | mamallapuram
# Processing Record 27 | ponta do sol
# Processing Record 28 | vaini
# Processing Record 29 | natal
# Processing Record 30 | punta arenas
# Processing Record 31 | ulladulla
# Processing Record 32 | saint george
# City not found. Skipping...
# Processing Record 33 | pangnirtung
# Processing Record 34 | jamestown
# Processing Record 35 | mahebourg
# Processing Record 36 | cidreira
# City not found. Skipping...
# Processing Record 37 | sarangani
# Processing Record 38 | kodinsk
# Processing Record 39 | mugur-aksy
# Processing Record 40 | esperance
# City not found. Skipping...
# Processing Record 41 | padang
# Processing Record 42 | busselton
# Processing Record 43 | cape town
# City not found. Skipping...
# Processing Record 44 | severo-kurilsk
# Processing Record 45 | lazarev
# Processing Record 46 | chernyshevskiy
# City not found. Skipping...
# Processing Record 47 | nome
# Processing Record 48 | castro
# City not found. Skipping...
# City not found. Skipping...
# Processing Record 49 | hofn
# Processing Record 50 | mantua
# Processing Record 51 | appleton
# Processing Record 52 | khatanga
# Processing Record 53 | hobart
# Processing Record 54 | sorong
# Processing Record 55 | buala
# Processing Record 56 | pevek
# Processing Record 57 | metro
# Processing Record 58 | kununurra
# Processing Record 59 | lagoa
# Processing Record 60 | isangel
# Processing Record 61 | klaksvik
# City not found. Skipping...
# Processing Record 62 | kaitangata
# City not found. Skipping...
# Processing Record 63 | guerrero negro
# Processing Record 64 | santa maria
# Processing Record 65 | acapulco
# Processing Record 66 | saskylakh
# Processing Record 67 | vydrino
# Processing Record 68 | labuhan
# Processing Record 69 | lebu
# Processing Record 70 | megion
# Processing Record 71 | kodiak
# Processing Record 72 | husavik
# City not found. Skipping...
# Processing Record 73 | bilma
# Processing Record 74 | tiznit
# Processing Record 75 | torbay
# Processing Record 76 | kenai
# Processing Record 77 | salta
# Processing Record 78 | bluff
# Processing Record 79 | george town
# Processing Record 80 | klyuchi
# Processing Record 81 | rundu
# City not found. Skipping...
# Processing Record 82 | tokur
# Processing Record 83 | nouadhibou
# Processing Record 84 | lasa
# Processing Record 85 | seymchan
# City not found. Skipping...
# Processing Record 86 | elizabeth city
# City not found. Skipping...
# Processing Record 87 | asuncion
# Processing Record 88 | leningradskiy
# Processing Record 89 | huarmey
# Processing Record 90 | touros
# Processing Record 91 | faanui
# Processing Record 92 | port alfred
# Processing Record 93 | artyom
# Processing Record 94 | sao filipe
# Processing Record 95 | meulaboh
# Processing Record 96 | tuktoyaktuk
# Processing Record 97 | concepcion del uruguay
# City not found. Skipping...
# City not found. Skipping...
# Processing Record 98 | new norfolk
# Processing Record 99 | keningau
# Processing Record 100 | arraial do cabo
# Processing Record 101 | kanakapura
# City not found. Skipping...
# Processing Record 102 | georgetown
# Processing Record 103 | sitka
# Processing Record 104 | kavieng
# Processing Record 105 | bendigo
# City not found. Skipping...
# Processing Record 106 | iqaluit
# Processing Record 107 | baherden
# Processing Record 108 | east london
# Processing Record 109 | nishihara
# Processing Record 110 | agulu
# Processing Record 111 | avarua
# Processing Record 112 | saint-gabriel
# Processing Record 113 | sao jose da coroa grande
# Processing Record 114 | tasiilaq
# Processing Record 115 | upernavik
# Processing Record 116 | fernie
# Processing Record 117 | ronneby
# Processing Record 118 | silvania
# Processing Record 119 | koutsouras
# Processing Record 120 | pilna
# Processing Record 121 | pemberton
# Processing Record 122 | isla mujeres
# Processing Record 123 | puerto ayora
# Processing Record 124 | waingapu
# Processing Record 125 | hithadhoo
# Processing Record 126 | vilhena
# Processing Record 127 | bani walid
# Processing Record 128 | margate
# Processing Record 129 | brae
# Processing Record 130 | bontang
# Processing Record 131 | general roca
# Processing Record 132 | caravelas
# City not found. Skipping...
# Processing Record 133 | victoria
# Processing Record 134 | beringovskiy
# Processing Record 135 | barrow
# Processing Record 136 | russell
# Processing Record 137 | zaraysk
# Processing Record 138 | saint-pierre
# Processing Record 139 | kalianget
# Processing Record 140 | qobustan
# Processing Record 141 | atuona
# City not found. Skipping...
# Processing Record 142 | shingu
# Processing Record 143 | kaeo
# Processing Record 144 | at-bashi
# City not found. Skipping...
# Processing Record 145 | gushikawa
# Processing Record 146 | portland
# Processing Record 147 | bitung
# Processing Record 148 | suntar
# Processing Record 149 | svetlaya
# Processing Record 150 | mayor pablo lagerenza
# Processing Record 151 | lavrentiya
# Processing Record 152 | kutum
# Processing Record 153 | mugango
# Processing Record 154 | hammerfest
# Processing Record 155 | karratha
# Processing Record 156 | shenzhen
# Processing Record 157 | norman wells
# Processing Record 158 | rena
# Processing Record 159 | ilulissat
# Processing Record 160 | yaan
# Processing Record 161 | bambous virieux
# Processing Record 162 | coihaique
# Processing Record 163 | lata
# Processing Record 164 | cabo san lucas
# Processing Record 165 | walvis bay
# Processing Record 166 | aksha
# Processing Record 167 | kokstad
# Processing Record 168 | lubango
# Processing Record 169 | guarapari
# Processing Record 170 | yumen
# Processing Record 171 | dunedin
# Processing Record 172 | nanortalik
# Processing Record 173 | airai
# Processing Record 174 | enshi
# Processing Record 175 | mozarlandia
# Processing Record 176 | cosmopolis
# City not found. Skipping...
# Processing Record 177 | omboue
# Processing Record 178 | comarapa
# Processing Record 179 | zhezkazgan
# Processing Record 180 | fortuna
# Processing Record 181 | denpasar
# Processing Record 182 | kahului
# Processing Record 183 | aklavik
# Processing Record 184 | tortoli
# City not found. Skipping...
# Processing Record 185 | sile
# City not found. Skipping...
# Processing Record 186 | fare
# Processing Record 187 | parana
# Processing Record 188 | thyolo
# Processing Record 189 | atar
# Processing Record 190 | capreol
# Processing Record 191 | arlit
# Processing Record 192 | kieta
# Processing Record 193 | port elizabeth
# Processing Record 194 | vanavara
# Processing Record 195 | hamilton
# Processing Record 196 | aqtobe
# Processing Record 197 | egvekinot
# Processing Record 198 | forbes
# Processing Record 199 | paamiut
# Processing Record 200 | sao gabriel da cachoeira
# Processing Record 201 | yining
# Processing Record 202 | te anau
# Processing Record 203 | mount isa
# Processing Record 204 | tiksi
# Processing Record 205 | mackay
# Processing Record 206 | taltal
# City not found. Skipping...
# Processing Record 207 | los llanos de aridane
# Processing Record 208 | lokoja
# Processing Record 209 | carnarvon
# City not found. Skipping...
# Processing Record 210 | elko
# Processing Record 211 | batagay-alyta
# Processing Record 212 | fukue
# Processing Record 213 | sassandra
# Processing Record 214 | vestmanna
# Processing Record 215 | samarkand
# Processing Record 216 | deputatskiy
# Processing Record 217 | vardo
# Processing Record 218 | lezajsk
# Processing Record 219 | aberfoyle
# City not found. Skipping...
# Processing Record 220 | souillac
# Processing Record 221 | steamboat springs
# Processing Record 222 | tazovskiy
# Processing Record 223 | namtsy
# Processing Record 224 | takoradi
# Processing Record 225 | yarada
# Processing Record 226 | praia da vitoria
# Processing Record 227 | erzurum
# Processing Record 228 | hambantota
# Processing Record 229 | rabo de peixe
# Processing Record 230 | chapais
# Processing Record 231 | oxford
# Processing Record 232 | ostrovnoy
# Processing Record 233 | xining
# Processing Record 234 | port-gentil
# Processing Record 235 | strezhevoy
# Processing Record 236 | clyde river
# Processing Record 237 | baghdad
# Processing Record 238 | port moresby
# Processing Record 239 | upata
# City not found. Skipping...
# Processing Record 240 | killybegs
# Processing Record 241 | muzhi
# City not found. Skipping...
# Processing Record 242 | nikolskoye
# Processing Record 243 | hailar
# Processing Record 244 | athabasca
# Processing Record 245 | prachuap khiri khan
# Processing Record 246 | kharp
# Processing Record 247 | sisimiut
# Processing Record 248 | gumdag
# Processing Record 249 | chiredzi
# Processing Record 250 | qaanaaq
# Processing Record 251 | lithgow
# Processing Record 252 | chama
# Processing Record 253 | sinnamary
# Processing Record 254 | yulara
# Processing Record 255 | santa cruz del norte
# Processing Record 256 | broome
# Processing Record 257 | solnechnyy
# City not found. Skipping...
# Processing Record 258 | dawlatabad
# Processing Record 259 | codrington
# Processing Record 260 | lianzhou
# City not found. Skipping...
# Processing Record 261 | hanzhong
# City not found. Skipping...
# Processing Record 262 | saint-augustin
# Processing Record 263 | vila velha
# City not found. Skipping...
# Processing Record 264 | nyurba
# Processing Record 265 | samarai
# Processing Record 266 | dickinson
# Processing Record 267 | kapaa
# Processing Record 268 | banda aceh
# Processing Record 269 | bongandanga
# Processing Record 270 | kaihua
# Processing Record 271 | mount gambier
# Processing Record 272 | darhan
# Processing Record 273 | port macquarie
# Processing Record 274 | bathsheba
# Processing Record 275 | erzin
# Processing Record 276 | swan hill
# Processing Record 277 | dera bugti
# City not found. Skipping...
# Processing Record 278 | mazatlan
# Processing Record 279 | port lincoln
# Processing Record 280 | bethel
# Processing Record 281 | haapiti
# City not found. Skipping...
# Processing Record 282 | lompoc
# Processing Record 283 | cuamba
# Processing Record 284 | nargana
# Processing Record 285 | valu lui traian
# Processing Record 286 | sambava
# Processing Record 287 | mayskiy
# Processing Record 288 | christchurch
# Processing Record 289 | vangaindrano
# Processing Record 290 | tonneins
# Processing Record 291 | belyy yar
# Processing Record 292 | tucurui
# Processing Record 293 | srednekolymsk
# Processing Record 294 | mogadishu
# Processing Record 295 | alibag
# Processing Record 296 | ucluelet
# Processing Record 297 | geraldton
# Processing Record 298 | sur
# Processing Record 299 | tuatapere
# Processing Record 300 | ribeira grande
# Processing Record 301 | pavilosta
# Processing Record 302 | tautira
# Processing Record 303 | coahuayana
# Processing Record 304 | nacogdoches
# Processing Record 305 | tezu
# Processing Record 306 | okato
# Processing Record 307 | camocim
# Processing Record 308 | balsas
# Processing Record 309 | ancud
# Processing Record 310 | feicheng
# Processing Record 311 | dingle
# Processing Record 312 | mahon
# Processing Record 313 | gander
# Processing Record 314 | kharan
# Processing Record 315 | sundsvall
# Processing Record 316 | santa vitoria do palmar
# Processing Record 317 | bodmin
# Processing Record 318 | phangnga
# Processing Record 319 | roura
# Processing Record 320 | albi
# City not found. Skipping...
# Processing Record 321 | robertson
# Processing Record 322 | samana
# Processing Record 323 | sao joao da barra
# City not found. Skipping...
# Processing Record 324 | constitucion
# Processing Record 325 | sao felix do xingu
# Processing Record 326 | leshukonskoye
# Processing Record 327 | zlobin
# Processing Record 328 | katsuura
# Processing Record 329 | amarante do maranhao
# Processing Record 330 | chokurdakh
# Processing Record 331 | maraa
# Processing Record 332 | luderitz
# Processing Record 333 | hualmay
# Processing Record 334 | trairi
# Processing Record 335 | morant bay
# Processing Record 336 | rawson
# Processing Record 337 | poum
# City not found. Skipping...
# Processing Record 338 | marawi
# Processing Record 339 | saint-louis
# Processing Record 340 | udachnyy
# Processing Record 341 | bonga
# Processing Record 342 | sorland
# Processing Record 343 | kattivakkam
# Processing Record 344 | irtyshskiy
# Processing Record 345 | manta
# Processing Record 346 | barranca
# Processing Record 347 | marzuq
# Processing Record 348 | pangkalanbuun
# Processing Record 349 | cherskiy
# Processing Record 350 | valparaiso
# Processing Record 351 | anlu
# Processing Record 352 | salalah
# Processing Record 353 | severodvinsk
# Processing Record 354 | dong hoi
# Processing Record 355 | karachi
# Processing Record 356 | telimele
# Processing Record 357 | san juan
# Processing Record 358 | kindersley
# City not found. Skipping...
# Processing Record 359 | saint anthony
# Processing Record 360 | puerto leguizamo
# Processing Record 361 | urucui
# Processing Record 362 | cachoeira do sul
# Processing Record 363 | san jose
# Processing Record 364 | stratford
# Processing Record 365 | synya
# Processing Record 366 | opuwo
# Processing Record 367 | pavino
# Processing Record 368 | cristalina
# Processing Record 369 | novyy urengoy
# Processing Record 370 | siocon
# Processing Record 371 | general elizardo aquino
# Processing Record 372 | port pirie
# Processing Record 373 | pyapon
# City not found. Skipping...
# Processing Record 374 | ambilobe
# Processing Record 375 | ugoofaaru
# Processing Record 376 | adrar
# Processing Record 377 | polson
# Processing Record 378 | fukuma
# Processing Record 379 | qaqortoq
# Processing Record 380 | kloulklubed
# Processing Record 381 | tiarei
# Processing Record 382 | maragogi
# Processing Record 383 | saint-georges
# Processing Record 384 | gorontalo
# Processing Record 385 | la ronge
# Processing Record 386 | abu dhabi
# Processing Record 387 | saldanha
# Processing Record 388 | bima
# Processing Record 389 | sola
# Processing Record 390 | talas
# Processing Record 391 | winnemucca
# Processing Record 392 | grand-santi
# Processing Record 393 | vao
# City not found. Skipping...
# Processing Record 394 | san patricio
# Processing Record 395 | omsukchan
# Processing Record 396 | bantou
# Processing Record 397 | ust-tsilma
# Processing Record 398 | matara
# Processing Record 399 | winnipeg
# Processing Record 400 | visby
# Processing Record 401 | havoysund
# Processing Record 402 | bhainsdehi
# Processing Record 403 | le passage
# City not found. Skipping...
# Processing Record 404 | ovalle
# Processing Record 405 | zyryanovsk
# Processing Record 406 | joshimath
# Processing Record 407 | golden
# Processing Record 408 | athmallik
# Processing Record 409 | mitsamiouli
# Processing Record 410 | karasjok
# Processing Record 411 | turukhansk
# Processing Record 412 | gurupi
# Processing Record 413 | naliya
# Processing Record 414 | port blair
# Processing Record 415 | pisco
# Processing Record 416 | grindavik
# Processing Record 417 | cockburn town
# Processing Record 418 | verkhnyaya khava
# Processing Record 419 | aizawl
# Processing Record 420 | hirara
# Processing Record 421 | gudalur
# Processing Record 422 | bermejo
# Processing Record 423 | sungaipenuh
# City not found. Skipping...
# Processing Record 424 | mulege
# City not found. Skipping...
# Processing Record 425 | tenenkou
# Processing Record 426 | broken hill
# Processing Record 427 | jiaxing
# Processing Record 428 | vestmannaeyjar
# Processing Record 429 | lazaro cardenas
# Processing Record 430 | mweka
# Processing Record 431 | waynesville
# Processing Record 432 | mastic beach
# City not found. Skipping...
# Processing Record 433 | aloleng
# Processing Record 434 | gamba
# Processing Record 435 | algiers
# City not found. Skipping...
# Processing Record 436 | vila franca do campo
# City not found. Skipping...
# Processing Record 437 | quelimane
# Processing Record 438 | hay river
# Processing Record 439 | axim
# Processing Record 440 | mitu
# Processing Record 441 | murupara
# Processing Record 442 | khipro
# Processing Record 443 | dudinka
# Processing Record 444 | benguela
# Processing Record 445 | karatau
# Processing Record 446 | lorengau
# Processing Record 447 | manggar
# Processing Record 448 | bowen
# Processing Record 449 | smithville
# Processing Record 450 | viedma
# Processing Record 451 | hukuntsi
# Processing Record 452 | antalaha
# Processing Record 453 | noumea
# Processing Record 454 | olinda
# Processing Record 455 | salisbury
# Processing Record 456 | nevinnomyssk
# Processing Record 457 | gizo
# Processing Record 458 | seoul
# Processing Record 459 | peniche
# Processing Record 460 | svetlogorsk
# City not found. Skipping...
# Processing Record 461 | moron
# Processing Record 462 | itaituba
# Processing Record 463 | grootegast
# Processing Record 464 | old orchard beach
# City not found. Skipping...
# Processing Record 465 | boyolangu
# Processing Record 466 | bartica
# City not found. Skipping...
# Processing Record 467 | bocas del toro
# Processing Record 468 | carbondale
# Processing Record 469 | porto walter
# Processing Record 470 | longyearbyen
# Processing Record 471 | riyadh
# City not found. Skipping...
# Processing Record 472 | tessalit
# Processing Record 473 | bonavista
# Processing Record 474 | port said
# Processing Record 475 | nantucket
# Processing Record 476 | pimentel
# City not found. Skipping...
# City not found. Skipping...
# Processing Record 477 | port hardy
# Processing Record 478 | tondano
# Processing Record 479 | celestun
# Processing Record 480 | brindisi
# Processing Record 481 | mayo
# Processing Record 482 | kruisfontein
# Processing Record 483 | itoman
# Processing Record 484 | nuuk
# Processing Record 485 | kandi
# City not found. Skipping...
# Processing Record 486 | hasaki
# Processing Record 487 | alyangula
# Processing Record 488 | sikonge
# Processing Record 489 | narsaq
# Processing Record 490 | sistranda
# Processing Record 491 | kidal
# Processing Record 492 | praya
# Processing Record 493 | zhanaozen
# City not found. Skipping...
# Processing Record 494 | tarata
# City not found. Skipping...
# Processing Record 495 | oyama
# Processing Record 496 | faya
# Processing Record 497 | tsiroanomandidy
# Processing Record 498 | san ignacio
# Processing Record 499 | lodja
# City not found. Skipping...
# Processing Record 500 | paluan
# Processing Record 501 | talara
# Processing Record 502 | nelson bay
# Processing Record 503 | balaipungut
# Processing Record 504 | kolondieba
# Processing Record 505 | poronaysk
# Processing Record 506 | grafton
# Processing Record 507 | mgandu
# Processing Record 508 | lexington
# City not found. Skipping...
# Processing Record 509 | tomaszow mazowiecki
# Processing Record 510 | takhtamygda
# Processing Record 511 | pointe michel
# Processing Record 512 | wanxian
# Processing Record 513 | nueve de julio
# Processing Record 514 | banjar
# Processing Record 515 | finnsnes
# Processing Record 516 | ust-maya
# Processing Record 517 | fairbanks
# Processing Record 518 | iquitos
# Processing Record 519 | wajir
# Processing Record 520 | belen
# Processing Record 521 | makat
# Processing Record 522 | hearst
# Processing Record 523 | harkany
# Processing Record 524 | makakilo city
# Processing Record 525 | honningsvag
# Processing Record 526 | san cristobal
# Processing Record 527 | alta floresta
# City not found. Skipping...
# Processing Record 528 | tranby
# Processing Record 529 | homer
# Processing Record 530 | yar-sale
# Processing Record 531 | gore
# Processing Record 532 | talnakh
# Processing Record 533 | ukiah
# Processing Record 534 | kahta
# Processing Record 535 | bandarbeyla
# Processing Record 536 | progreso
# Processing Record 537 | ekhabi
# Processing Record 538 | bolshaya martynovka
# Processing Record 539 | kerrobert
# Processing Record 540 | shache
# Processing Record 541 | foso
# Processing Record 542 | port hedland
# Processing Record 543 | skibbereen
# Processing Record 544 | roma
# Processing Record 545 | prieska
# City not found. Skipping...
# Processing Record 546 | ayan
# Processing Record 547 | yazd
# Processing Record 548 | mandali
# Processing Record 549 | belaya gora
# Processing Record 550 | marsh harbour
# Processing Record 551 | san borja
# Processing Record 552 | hauterive
# Processing Record 553 | nago

# %%
print(len(lat))
print(len(cloud))
print(len(temp))
print(len(humidity))
# Out:
# 553
# 553
# 553
# 553

# %%
df = pd.DataFrame(list(zip(cities, lat, temp, humidity, cloud, wind)), 
               columns =['City', 'Latitude', 'Temperature', 'Humidity', 'Cloud', 'Wind'])

# %%
df.head()
# Out:
#           City  Latitude  Temperature  Humidity  Cloud  Wind
# 0  provideniya     64.42         9.05        94    100  6.49
# 1       dikson     73.51         4.95        99    100  2.98
# 2   santa rosa    -36.62        12.35        94    100  3.58
# 3     hermanus    -34.42        16.80        55      9  3.13
# 4   bredasdorp    -34.53        15.30        41      6  4.10

# %%
export_csv = df.to_csv("weather.csv"), r'C:/Desktop/Ahmad_DataBootCampHW/Homework 6/'

# %%
latitude = df.iloc[:,1]
city = df.iloc[:,0]
temperature = df.iloc[:,2]
humid = df.iloc[:,3]
cloudiness = df.iloc[:,4]
windiness = df.iloc[:,5]

# %%
latitude_temp = plt.scatter(latitude, temperature, color="cornflowerblue", 
                        marker="o", edgecolor="black")

plt.title("City Latitude VS Max Temperature")
plt.xlabel("Latitude)")
plt.ylabel("Max Temperature (C)")

plt.grid(b=True)

# %%
latitude_humidity = plt.scatter(latitude, humidity, color="cornflowerblue", 
                        marker="o", edgecolor="black")

plt.title("City Latitude VS Humidity")
plt.xlabel("Latitude)")
plt.ylabel("Humidity (%)")

plt.grid(b=True)

# %%
latitude_cloudiness = plt.scatter(latitude, cloudiness, color="cornflowerblue", 
                        marker="o", edgecolor="black")

plt.title("City Latitude VS Cloudiness")
plt.xlabel("Latitude)")
plt.ylabel("Cloudiness (%)")

plt.grid(b=True)

# %%
latitude_wind = plt.scatter(latitude, windiness, color="cornflowerblue", 
                        marker="o", edgecolor="black")

plt.title("City Latitude VS Wind Speed")
plt.xlabel("Latitude)")
plt.ylabel("Wind Speed (mph)")

plt.grid(b=True)

# %%
plt.savefig("City Latitude VS Cloudiness.png")
plt.savefig("City Latitude VS Wind Speed.png")
plt.savefig("City Latitude VS Humidity.png")
